# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from importlib import reload
import stock
import base_analysis
import return_analysis as ra

# %matplotlib inline
# Out:
# /home/ryohayama/.local/lib/python3.6/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %% [markdown]
# # INTC

# %%
reload(stock)
reload(base_analysis)
reload(ra)
# Out:
# <module 'return_analysis' from '/home/ryohayama/Python/DowJones/return_analysis.py'>

# %%
intc = stock.Stock('INTC')

# %%
intc_ra = ra.ReturnAnalysis(intc, future=True)

# %%
intc_ra.print_info()
# Out:
# ============ INTC Basic Info ============
# Start Date - 2010-01-04
#  End  Date - 2017-12-18
# Number of data points - 2005
# Number of missing data points - 0

# %%
intc_ra.plot()

# %%
intc_ra.hist(bins=100)

# %%
intc_ra.boxplot(bins=40)

# %%
intc_ra.violinplot()

# %%
intc_ra.stats()
# Out:
#                  median      mean       std       min       max  5_percentile  \
# 1day_return    0.000508  0.000397  0.014360 -0.095432  0.088666     -0.023056
# 10day_return   0.003333  0.003710  0.044799 -0.146344  0.168895     -0.072526
# 20day_return   0.009752  0.007713  0.063750 -0.186741  0.191764     -0.102014
# 50day_return   0.016928  0.019228  0.097274 -0.227366  0.306687     -0.145653
# 100day_return  0.032316  0.032319  0.123033 -0.309629  0.349895     -0.177623
# 200day_return  0.068722  0.066177  0.155309 -0.343852  0.433461     -0.234299
#
#                95_percentile  frac_positive  frac_negative  n_points
# 1day_return         0.023102       0.518463       0.468064      2004
# 10day_return        0.079085       0.536842       0.458647      1995
# 20day_return        0.106320       0.561209       0.435768      1985
# 50day_return        0.178686       0.557033       0.439898      1955
# 100day_return       0.256339       0.604724       0.393176      1905
# 200day_return       0.331490       0.708033       0.291967      1805

# %% [markdown]
# # AMZN

# %%
amzn_ra = ra.ReturnAnalysis('AMZN', future=True)

# %%
amzn_ra.print_info()
# Out:
# ============ AMZN Basic Info ============
# Start Date - 2010-01-04
#  End  Date - 2017-12-18
# Number of data points - 2005
# Number of missing data points - 0

# %%
amzn_ra.plot()

# %%
amzn_ra.hist(bins=100)

# %%
amzn_ra.boxplot(bins=40)

# %%
amzn_ra.violinplot()

# %%
amzn_ra.stats()
# Out:
#                  median      mean       std       min       max  5_percentile  \
# 1day_return    0.000891  0.001090  0.019581 -0.135325  0.146225     -0.027146
# 10day_return   0.010671  0.010975  0.058315 -0.231957  0.227969     -0.086815
# 20day_return   0.027497  0.022331  0.078788 -0.247978  0.300661     -0.109398
# 50day_return   0.060381  0.055759  0.117750 -0.338426  0.328244     -0.158173
# 100day_return  0.120184  0.109170  0.149265 -0.305814  0.476536     -0.158969
# 200day_return  0.241269  0.224679  0.177194 -0.334295  0.795385     -0.094567
#
#                95_percentile  frac_positive  frac_negative  n_points
# 1day_return         0.027746       0.524451       0.473054      2004
# 10day_return        0.105798       0.588471       0.411028      1995
# 20day_return        0.144578       0.641310       0.358690      1985
# 50day_return        0.234413       0.700256       0.298721      1955
# 100day_return       0.355702       0.782152       0.217848      1905
# 200day_return       0.521258       0.888089       0.111911      1805

# %% [markdown]
# # NTEC

# %%
ntec_ra = ra.ReturnAnalysis('NTEC', future=True)

# %%
ntec_ra.ticker
# Out:
# 'NTEC'

# %%
ntec_ra.print_info()
# Out:
# ============ NTEC Basic Info ============
# Start Date - 2015-08-04
#  End  Date - 2017-12-18
# Number of data points - 600
# Number of missing data points - 0

# %%
ntec_ra.plot()

# %%
ntec_ra.hist(bins=100)

# %%
ntec_ra.boxplot(bins=40)

# %%
ntec_ra.violinplot()

# %%
ntec_ra.stats()
# Out:
#                  median      mean       std       min       max  5_percentile  \
# 1day_return    0.000000 -0.000338  0.031357 -0.276558  0.125769     -0.048815
# 10day_return  -0.009009 -0.002540  0.096026 -0.335207  0.292823     -0.140855
# 20day_return  -0.008138 -0.002235  0.150896 -0.373817  0.449170     -0.260502
# 50day_return   0.000000  0.014923  0.225328 -0.608887  0.560926     -0.386437
# 100day_return  0.055315  0.034148  0.282640 -0.650453  0.624097     -0.449751
# 200day_return  0.111824  0.113077  0.226428 -0.505285  0.617544     -0.261499
#
#                95_percentile  frac_positive  frac_negative  n_points
# 1day_return         0.044480       0.419032       0.459098       599
# 10day_return        0.191066       0.444068       0.525424       590
# 20day_return        0.287826       0.462069       0.517241       580
# 50day_return        0.426268       0.490909       0.494545       550
# 100day_return       0.487654       0.602000       0.392000       500
# 200day_return       0.491408       0.700000       0.297500       400
