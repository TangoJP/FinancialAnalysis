# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from importlib import reload
import stock
import return_analysis as ra

# %matplotlib inline
# Out:
# /home/ryohayama/.local/lib/python3.6/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %% [markdown]
# # INTC

# %%
intc = stock.Stock('INTC')

# %%
reload(ra)
# Out:
# <module 'return_analysis' from '/home/ryohayama/Python/DowJones/return_analysis.py'>

# %%
intc_ra = ra.ReturnAnalysis(intc)

# %%
intc_ra.print_info()
# Out:
# ============ INTC Basic Info ============
# Start Date - 2010-01-04
#  End  Date - 2017-12-15
# Number of data points - 2004
# Number of missing data points - 0

# %%
intc_ra.plot()

# %%
intc_ra.hist(bins=100)

# %%
intc_ra.boxplot(bins=40)

# %%
intc_ra.violinplot()

# %%
intc_ra.stats()
# Out:
#                  median      mean       std       min       max  5_percentile  \
# daily_return   0.000487  0.000378  0.014339 -0.095432  0.088666     -0.023057
# 10day_return   0.003320  0.003692  0.044803 -0.146344  0.168895     -0.072559
# 20day_return   0.009651  0.007699  0.063762 -0.186741  0.191764     -0.102021
# 50day_return   0.016916  0.019158  0.097250 -0.227366  0.306687     -0.145665
# 100day_return  0.032315  0.032189  0.122934 -0.309629  0.349895     -0.177679
# 200day_return  0.068676  0.066068  0.155283 -0.343852  0.433461     -0.234458
#
#                95_percentile  frac_positive  frac_negative  n_points
# daily_return        0.023029       0.518223       0.468298      2003
# 10day_return        0.079098       0.536610       0.458877      1994
# 20day_return        0.106341       0.560988       0.435988      1984
# 50day_return        0.178743       0.556807       0.440123      1954
# 100day_return       0.255687       0.604517       0.393382      1904
# ...

# %% [markdown]
# # AMZN

# %%
amzn_ra = ra.ReturnAnalysis('AMZN')

# %%
amzn_ra.print_info()
# Out:
# ============ AMZN Basic Info ============
# Start Date - 2010-01-04
#  End  Date - 2017-12-15
# Number of data points - 2004
# Number of missing data points - 0

# %%
amzn_ra.plot()

# %%
amzn_ra.hist(bins=100)

# %%
amzn_ra.boxplot(bins=40)

# %%
amzn_ra.violinplot()

# %%
amzn_ra.stats()
# Out:
#                  median      mean       std       min       max  5_percentile  \
# daily_return   0.000885  0.001086  0.019585 -0.135325  0.146225     -0.027156
# 10day_return   0.010645  0.010956  0.058323 -0.231957  0.227969     -0.086822
# 20day_return   0.027492  0.022316  0.078805 -0.247978  0.300661     -0.109403
# 50day_return   0.060351  0.055692  0.117744 -0.338426  0.328244     -0.158176
# 100day_return  0.120127  0.109159  0.149304 -0.305814  0.476536     -0.159004
# 200day_return  0.241148  0.224615  0.177222 -0.334295  0.795385     -0.094646
#
#                95_percentile  frac_positive  frac_negative  n_points
# daily_return        0.027751       0.524214       0.473290      2003
# 10day_return        0.105822       0.588265       0.411234      1994
# 20day_return        0.144618       0.641129       0.358871      1984
# 50day_return        0.234438       0.700102       0.298874      1954
# 100day_return       0.355784       0.782038       0.217962      1904
# ...

# %% [markdown]
# # NTEC

# %%
ntec_ra = ra.ReturnAnalysis('NTEC')

# %%
ntec_ra.ticker
# Out:
# 'NTEC'

# %%
ntec_ra.print_info()
# Out:
# ============ NTEC Basic Info ============
# Start Date - 2015-08-04
#  End  Date - 2017-12-15
# Number of data points - 599
# Number of missing data points - 0

# %%
ntec_ra.plot()

# %%
ntec_ra.hist(bins=100)

# %%
ntec_ra.boxplot(bins=40)

# %%
ntec_ra.violinplot()

# %%
ntec_ra.stats()
# Out:
#                  median      mean       std       min       max  5_percentile  \
# daily_return   0.000000 -0.000322  0.031381 -0.276558  0.125769     -0.048828
# 10day_return  -0.008969 -0.002333  0.095976 -0.335207  0.292823     -0.140880
# 20day_return  -0.008075 -0.001875  0.150777 -0.373817  0.449170     -0.260819
# 50day_return   0.000000  0.016058  0.223958 -0.608887  0.560926     -0.379519
# 100day_return  0.055570  0.034466  0.282833 -0.650453  0.624097     -0.449830
# 200day_return  0.110203  0.113060  0.226711 -0.505285  0.617544     -0.261518
#
#                95_percentile  frac_positive  frac_negative  n_points
# daily_return        0.044494       0.419732       0.458194       598
# 10day_return        0.191109       0.444822       0.524618       589
# 20day_return        0.287970       0.462867       0.516408       579
# 50day_return        0.426268       0.491803       0.493625       549
# 100day_return       0.488357       0.603206       0.390782       499
# ...
